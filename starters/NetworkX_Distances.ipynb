# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import networkx as nx

# %%
import json
from networkx.readwrite import json_graph
def read_graph_from_json(json_file):
    with open(json_file) as f:
        data = json.load(f)
    return json_graph.adjacency_graph(data)

# %%
# read the graph my_network.json from file

# %%
# calculate the distance from node 1 to all others:

# %%
# print the distance from 1 to all other nodes

# %%
# get shortest paths from 1 to all other nodes

# %%
# print the actual paths

# %%
# compute a shortest path from node 1 to node 8
